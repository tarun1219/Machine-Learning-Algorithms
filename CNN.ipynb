# %%
# !git clone https://github.com/laxmimerit/dog-cat-full-dataset
# Out:
# fatal: destination path 'dog-cat-full-dataset' already exists and is not an empty directory.

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('dog-cat-full-dataset/data/train',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 20000 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dog-cat-full-dataset/data/test',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 5000 images belonging to 2 classes.

# %%
cnn=tf.keras.models.Sequential()
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu',input_shape=[64,64,3]))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=128,activation='relu'))

# %%
cnn.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %%
cnn.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
cnn.fit(x=training_set,validation_data=test_set,epochs=25)
# Out:
# Epoch 1/25
# 625/625 [==============================] - 168s 269ms/step - loss: 0.6150 - accuracy: 0.6467 - val_loss: 0.5288 - val_accuracy: 0.7386
# Epoch 2/25
# 625/625 [==============================] - 168s 268ms/step - loss: 0.5232 - accuracy: 0.7398 - val_loss: 0.4894 - val_accuracy: 0.7654
# Epoch 3/25
# 625/625 [==============================] - 167s 267ms/step - loss: 0.4828 - accuracy: 0.7671 - val_loss: 0.4475 - val_accuracy: 0.7892
# Epoch 4/25
# 625/625 [==============================] - 165s 264ms/step - loss: 0.4586 - accuracy: 0.7836 - val_loss: 0.4437 - val_accuracy: 0.7952
# Epoch 5/25
# 625/625 [==============================] - 165s 263ms/step - loss: 0.4379 - accuracy: 0.7932 - val_loss: 0.4156 - val_accuracy: 0.8028
# Epoch 6/25
# 625/625 [==============================] - 165s 264ms/step - loss: 0.4223 - accuracy: 0.8032 - val_loss: 0.4212 - val_accuracy: 0.8026
# Epoch 7/25
# ...

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files
uploaded = files.upload()

#test_image=image.load_img
# Out:
#      <input type="file" id="files-9955f746-d3df-4c86-89a6-74a4c50caef2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9955f746-d3df-4c86-89a6-74a4c50caef2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dog.4003.jpg to dog.4003.jpg

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('dog.4003.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] ==1 :
    prediction = 'dog'
else:
    prediction = 'cat'
print(prediction)
# Out:
# cat
